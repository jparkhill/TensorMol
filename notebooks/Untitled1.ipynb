# %%
from IPython.core.debugger import Tracer; Tracer()() 
import TensorMol as tm

# %%
from IPython import embed; embed()

# %%
import TensorMol as tm

# %%
import numpy as np

# %%
import TensorMol as tm

# %%
from __future__ import print_function

# %%
print("test")

# %%
from TensorMol import *

# %%
import pip
installed_packages = pip.get_installed_distributions()
installed_packages_list = sorted(["%s==%s" % (i.key, i.version)
     for i in installed_packages])
print(installed_packages_list)
# Out:
# ['alabaster==0.7.9', 'algopy==0.5.3', 'altgraph==0.10.2', 'appnope==0.1.0', 'apptools==4.4.0', 'babel==2.3.4', 'backports-abc==0.4', 'backports.shutil-get-terminal-size==1.0.0', 'bdist-mpkg==0.5.0', 'bonjour-py==0.3', 'certifi==2016.8.8', 'configobj==5.0.6', 'configparser==3.5.0', 'decorator==4.0.10', 'docutils==0.13.1', 'entrypoints==0.2.2', 'funcsigs==1.0.2', 'functools32==3.2.3.post2', 'h5py==2.6.0', 'imagesize==0.7.1', 'ipykernel==4.5.2', 'ipython-genutils==0.1.0', 'ipython==5.1.0', 'ipyvolume==0.2.3', 'ipywidgets==6.0.0b10', 'jinja2==2.8', 'jsonschema==2.5.1', 'jupyter-client==4.3.0', 'jupyter-core==4.1.1', 'macholib==1.5.1', 'markupsafe==0.23', 'matplotlib==1.3.1', 'mistune==0.7.3', 'mock==2.0.0', 'modulegraph==0.10.4', 'nbconvert==4.2.0', 'nbformat==4.3.0', 'notebook==4.4.1', 'numdifftools==0.9.17', 'numexpr==2.6.1', 'numpy==1.11.3', 'pandas==0.19.2', 'pathlib2==2.1.0', 'pbr==1.10.0', 'pexpect==4.2.1', 'pickleshare==0.7.4', 'pillow==3.3.0', 'pip==9.0.1', 'pockets==0.5.1', 'prompt-toolkit==1.0.7', 'protobuf==3.2.0', 'ptyprocess==0.5.1', 'py2app==0.7.3', 'pyface==5.1.0', 'pygments==2.1.3', 'pyobjc-core==2.5.1', 'pyobjc-framework-accounts==2.5.1', 'pyobjc-framework-addressbook==2.5.1', 'pyobjc-framework-applescriptkit==2.5.1', 'pyobjc-framework-applescriptobjc==2.5.1', 'pyobjc-framework-automator==2.5.1', 'pyobjc-framework-cfnetwork==2.5.1', 'pyobjc-framework-cocoa==2.5.1', 'pyobjc-framework-collaboration==2.5.1', 'pyobjc-framework-coredata==2.5.1', 'pyobjc-framework-corelocation==2.5.1', 'pyobjc-framework-coretext==2.5.1', 'pyobjc-framework-dictionaryservices==2.5.1', 'pyobjc-framework-eventkit==2.5.1', 'pyobjc-framework-exceptionhandling==2.5.1', 'pyobjc-framework-fsevents==2.5.1', 'pyobjc-framework-inputmethodkit==2.5.1', 'pyobjc-framework-installerplugins==2.5.1', 'pyobjc-framework-instantmessage==2.5.1', 'pyobjc-framework-latentsemanticmapping==2.5.1', 'pyobjc-framework-launchservices==2.5.1', 'pyobjc-framework-message==2.5.1', 'pyobjc-framework-opendirectory==2.5.1', 'pyobjc-framework-preferencepanes==2.5.1', 'pyobjc-framework-pubsub==2.5.1', 'pyobjc-framework-qtkit==2.5.1', 'pyobjc-framework-quartz==2.5.1', 'pyobjc-framework-screensaver==2.5.1', 'pyobjc-framework-scriptingbridge==2.5.1', 'pyobjc-framework-searchkit==2.5.1', 'pyobjc-framework-servicemanagement==2.5.1', 'pyobjc-framework-social==2.5.1', 'pyobjc-framework-syncservices==2.5.1', 'pyobjc-framework-systemconfiguration==2.5.1', 'pyobjc-framework-webkit==2.5.1', 'pyopenssl==0.13.1', 'pyparsing==2.0.1', 'pyqtgraph==0.9.10', 'python-dateutil==1.5', 'pytz==2013.7', 'pyzmq==15.4.0', 'requests==2.12.4', 'scikit-learn==0.18.1', 'scipy==0.13.0b1', 'setuptools==32.3.1', 'simplegeneric==0.8.1', 'singledispatch==3.4.0.3', 'six==1.10.0', 'sklearn==0.0', 'snowballstemmer==1.2.1', 'sphinx==1.5.1', 'sphinxcontrib-napoleon==0.6.1', 'tables==3.3.0', 'tensorflow==1.1.0', 'tensormol==0.1', 'terminado==0.6', 'tornado==4.4.1', 'traitlets==4.2.2', 'traits==4.5.0', 'traitsui==5.1.0', 'traittypes==0.0.6', 'unknown==0.0.0', 'wcwidth==0.1.7', 'werkzeug==0.12.1', 'wheel==0.29.0', 'widgetsnbextension==2.0.0b19', 'xattr==0.6.4', 'zope.interface==4.1.1']

# %%
import tensorflow as tf

# %%
import tensormol as tm

# %%
help('modules')

# %%
pip freeze

# %%
pip list
# Out:
#   File "<ipython-input-3-2df2a96bee40>", line 1
#     pip list
#            ^
# SyntaxError: invalid syntax

# %%
import sys as s
s.modules.keys()
# Out:
# ['traitlets.config.decorator',
#  'pip._vendor.distlib.socket',
#  'distutils.sysconfig',
#  'pygments.filters',
#  'IPython.utils.pprint',
#  'logging.weakref',
#  'pip._vendor.distlib._backport.pwd',
#  'pprint',
#  'prompt_toolkit.key_binding.bindings.vi',
#  'ipykernel.traitlets',
#  'pip.status_codes',
#  'IPython.terminal.sys',
#  'SocketServer',
#  'xml.etree.sys',
#  'IPython.terminal.embed',
#  'jupyter_core.sys',
#  'pip._vendor.collections',
#  'cmd',
#  'IPython.core.magics.auto',
#  'shlex',
#  'pip._vendor.requests.packages.urllib3.util.url',
#  'IPython.core.completerlib',
#  'zlib',
#  'ipywidgets.IPython',
#  'pkg_resources._vendor.pprint',
#  'ipywidgets.widgets.domwidget',
#  'pexpect.spawnbase',
#  'IPython.terminal.ipapp',
#  'IPython.core.excolors',
#  'pip._vendor.requests.packages.urllib3.exceptions',
#  'pkg_resources.extern.appdirs',
#  'zmq.backend.cython.error',
#  'tarfile',
#  'IPython.core.mimetypes',
#  'ntpath',
#  'pip._vendor.distlib._backport',
#  'IPython.utils.openpy',
#  'pip._vendor.ipaddress',
#  'prompt_toolkit.key_binding.weakref',
#  'prompt_toolkit.tempfile',
#  'codecs',
#  'pygments.codecs',
#  'traitlets.config.loader',
#  'zmq.eventloop',
#  'ptyprocess.errno',
#  'pygments.filters.pygments',
#  'prompt_toolkit.styles.__future__',
#  'IPython.core.usage',
#  'pip._vendor.packaging.requirements',
#  'pkg_resources._vendor.datetime',
#  'ctypes._ctypes',
#  '_heapq',
#  'zmq.sugar.constants',
#  'pip._vendor.html5lib.treebuilders.base',
#  'pexpect.time',
#  'zmq.backend.cython._poll',
#  'email.sys',
#  'prompt_toolkit.filters.utils',
#  'prompt_toolkit.six',
#  'cPickle',
#  'ipykernel.comm.ipykernel',
#  'IPython.utils.encoding',
#  'IPython.lib.os',
#  'zmq.backend.cython.cPickle',
#  'prompt_toolkit.enums',
#  'jupyter_client.sys',
#  'prompt_toolkit.styles.pygments',
#  'pkg_resources._vendor.copy',
#  'zmq.backend.cython.codecs',
#  'jupyter_client.blocking.jupyter_client',
#  'exceptions',
#  'pip._vendor.requests.collections',
#  'pygments.regexopt',
#  'logging.cStringIO',
#  'pip._vendor.packaging.__about__',
#  'email.message',
#  'ipykernel.zmq',
#  'email.MIMEBase',
#  'strop',
#  'IPython.core.history',
#  'ipython_genutils.textwrap',
#  'prompt_toolkit.abc',
#  'IPython.utils.ipstruct',
#  'pip._vendor.distlib.time',
#  'os.path',
#  'prompt_toolkit.eventloop.callbacks',
#  'email.base64mime',
#  'pip.wheel',
#  'pip._vendor.requests.packages.urllib3.packages._abcoll',
#  'pip._vendor.cachecontrol.wrapper',
#  'pexpect.exceptions',
#  'functools',
#  'pkg_resources._vendor.weakref',
#  'prompt_toolkit.subprocess',
#  'distutils.fancy_getopt',
#  'pip._vendor.distlib.re',
#  'uuid',
#  'imp',
#  'ipywidgets.widgets.ipykernel',
#  'IPython.utils.tempdir',
#  'backports.shutil_get_terminal_size.collections',
#  'zmq.zmq',
#  'pip._vendor.requests.io',
#  'IPython.extensions',
#  'pip._vendor.distlib.textwrap',
#  'zmq.eventloop.__future__',
#  'decorator',
#  'IPython.core.magics.execution',
#  'IPython.utils.imp',
#  'IPython.utils.sysinfo',
#  'pip._vendor.colorama.win32',
#  'IPython.testing.sys',
#  'IPython.core.magics.basic',
#  'IPython.terminal.pt_inputhooks',
#  'ipywidgets.widgets.widget_color',
#  'xml.parsers.pyexpat',
#  'IPython.core.tempfile',
#  're',
#  'pip.utils.ui',
#  'email.quopri',
#  'pip._vendor.html5lib',
#  'IPython.core.IPython',
#  'json.json',
#  'IPython.core.types',
#  'ipykernel.ctypes',
#  '_locale',
#  'logging',
#  'traceback',
#  'IPython.utils.coloransi',
#  'IPython.utils._process_posix',
#  'ipywidgets.widgets.widget_layout',
#  'IPython.terminal.IPython',
#  'traitlets.config.ast',
#  'pexpect',
#  'pip._vendor.cachecontrol.types',
#  'pkg_resources._vendor.packaging._compat',
#  'encodings.utf_16_be',
#  'pip._vendor.random',
#  'zmq.backend.cython._device',
#  'prompt_toolkit.utils',
#  'IPython.utils.os',
#  'pygments.styles.pygments',
#  'IPython.core.magics.code',
#  'pip._vendor.requests.sys',
#  'prompt_toolkit.reactive',
#  'keyword',
#  'ipython_genutils.random',
#  'pygments.lexers.fnmatch',
#  '_curses',
#  'IPython.utils.generics',
#  'pip._vendor.distlib.contextlib',
#  'pip._vendor.lockfile',
#  '__main__',
#  'prompt_toolkit.layout.re',
#  'pip._vendor.cachecontrol.re',
#  'prompt_toolkit.token',
#  'IPython.utils.terminal',
#  'ipykernel.iostream',
#  'IPython.terminal.os',
#  'email.MIMEMultipart',
#  'pexpect.ptyprocess',
#  'IPython.lib.clipboard',
#  'glob',
#  'prompt_toolkit.prompt_toolkit',
#  'zmq.sugar.cPickle',
#  'gzip',
#  '_sqlite3',
#  'ctypes.macholib',
#  'IPython.utils.wildcard',
#  'posixpath',
#  'pip._vendor.html5lib.treebuilders',
#  'random',
#  'zmq.sugar.context',
#  'pip._vendor.requests.sessions',
#  'pygments.operator',
#  'pygments.time',
#  'pip._vendor.cachecontrol.time',
#  'email.time',
#  'IPython.core.time',
#  'pkg_resources._vendor.warnings',
#  'pip._vendor.requests.json',
#  'xml.etree.ElementTree',
#  'pip._vendor.distlib._backport.re',
#  'ipywidgets.widgets.widget_image',
#  'prompt_toolkit.terminal.tty',
#  'ptyprocess.ptyprocess',
#  'traitlets.config.collections',
#  'prompt_toolkit.types',
#  'pip._vendor.html5lib._utils',
#  'IPython.core.prefilter',
#  'ipywidgets.widgets.widget_float',
#  'pyexpat.model',
#  'pkg_resources._vendor.six.moves',
#  'pip._vendor.distlib._backport.time',
#  'jupyter_core.paths',
#  'prompt_toolkit.key_binding.six',
#  'ipykernel.comm.traitlets',
#  'urllib',
#  'ipykernel.displayhook',
#  'pip._vendor.webencodings.codecs',
#  'IPython.core.atexit',
#  'pip._vendor.requests.StringIO',
#  'Queue',
#  'ctypes',
#  'IPython.lib.collections',
#  'ipykernel.__future__',
#  'IPython.core.magics.namespace',
#  'pip._vendor.progress.collections',
#  'IPython.terminal.shortcuts',
#  'IPython.core.magics.atexit',
#  'six.moves',
#  'IPython.terminal.logging',
#  'email.uu',
#  'IPython.testing',
#  'sqlite3.datetime',
#  'pygments.lexers.re',
#  'email.calendar',
#  'IPython.core.hooks',
#  'IPython.display',
#  'pkgutil',
#  'zmq.backend.cython',
#  'zmq.backend.os',
#  'pip._vendor.progress.math',
#  'pkg_resources._vendor.sys',
#  'jupyter_client.uuid',
#  'curses.sys',
#  'pip._vendor.requests.adapters',
#  'pip._vendor.requests.calendar',
#  'pip._vendor.requests.packages.urllib3.packages.ssl_match_hostname',
#  'prompt_toolkit.__future__',
#  'ptyprocess.util',
#  'storemagic',
#  'wcwidth.table_zero',
#  'email.random',
#  'ipykernel.thread',
#  'json.decoder',
#  'tornado.platform.auto',
#  'pkg_resources._vendor.appdirs',
#  'io',
#  'IPython.core.struct',
#  'distutils.ConfigParser',
#  'IPython.utils.random',
#  'jupyter_client.clientabc',
#  'pip._vendor.progress',
#  'prompt_toolkit.terminal.os',
#  'pip._vendor.requests.packages.urllib3',
#  'prompt_toolkit.weakref',
#  'wheel',
#  'IPython.core.macro',
#  'rfc822',
#  'prompt_toolkit.filters',
#  'pip._vendor.progress.datetime',
#  'jupyter_client.traitlets',
#  'distutils.sys',
#  'pkg_resources._vendor.packaging',
#  '_weakref',
#  'IPython.core.inputtransformer',
#  'pkg_resources.extern.pyparsing',
#  'urlparse',
#  'ctypes.macholib.dylib',
#  'pygments.cStringIO',
#  'pip._vendor.retrying',
#  'IPython.core',
#  'ipywidgets.widgets.widget_button',
#  '_bisect',
#  'ipykernel.pickleutil',
#  'pip._vendor.requests.struct',
#  'pip._vendor.pprint',
#  'distutils.command.types',
#  'ipython_genutils.path',
#  'IPython.utils.strdispatch',
#  'jupyter_client.random',
#  'pip.utils.outdated',
#  'sqlite3._sqlite3',
#  'collections',
#  'ConfigParser',
#  'IPython.extensions.sys',
#  'pkg_resources._vendor.packaging._structures',
#  'IPython.terminal.magics',
#  'textwrap',
#  'certifi.warnings',
#  'pip._vendor.requests.cookielib',
#  'tornado.util',
#  'pexpect.traceback',
#  'ipykernel.math',
#  'zmq.backend.cython._version',
#  'IPython.core.inputsplitter',
#  'pip._vendor.cachecontrol.caches.os',
#  'pip._vendor.packaging.markers',
#  'IPython.terminal.warnings',
#  'pip._vendor.requests.packages.urllib3.packages.six.moves',
#  'IPython.core.getopt',
#  'pygments.lexers._mapping',
#  'pygments.lexers.os',
#  'logging.traceback',
#  'tornado.stack_context',
#  'prompt_toolkit.terminal.array',
#  'IPython.core.argparse',
#  'pip._vendor.cachecontrol.io',
#  'mpl_toolkits',
#  'traitlets.config.ipython_genutils',
#  'pip._vendor.requests.os',
#  'pygments.os',
#  'prompt_toolkit.layout.dimension',
#  'pip._vendor.distlib.compat',
#  'pip._vendor.distlib.types',
#  'pip._vendor.distlib.py_compile',
#  'IPython.utils.contexts',
#  'marshal',
#  'pip._vendor.requests.time',
#  'IPython.lib.deepreload',
#  'jupyter_client.blocking.Queue',
#  'distutils.dir_util',
#  'distutils.command',
#  'prompt_toolkit.layout.itertools',
#  'pygments.formatters.fnmatch',
#  'pip._vendor.requests.packages.urllib3.util.request',
#  'IPython.utils.tokenutil',
#  '_socket',
#  'email.Utils',
#  'pip._vendor.distlib.sys',
#  'IPython.core.glob',
#  'IPython.core.abc',
#  'zmq.eventloop.zmq',
#  'prompt_toolkit.styles.prompt_toolkit',
#  'tokenize',
#  'pygments.formatters',
#  'curses.wrapper',
#  'zmq.backend',
#  'IPython.utils.pexpect',
#  'IPython.core.magics.pylab',
#  'IPython.paths',
#  'mimetools',
#  'pip._vendor.requests.certs',
#  'ipywidgets.widgets.interaction',
#  'pip._vendor.requests.compat',
#  'pip._vendor.requests.base64',
#  'prompt_toolkit.key_binding.bindings.scroll',
#  'traitlets.config.traitlets',
#  'IPython.core.string',
#  'pip._vendor.distlib._backport.copy',
#  'prompt_toolkit.os',
#  'jupyter_client.client',
#  'wcwidth.wcwidth',
#  'pip.locations',
#  'genericpath',
#  'IPython.utils.io',
#  'urllib2',
#  'ipykernel.time',
#  'ipykernel.os',
#  'ctypes.ctypes',
#  'IPython.utils.functools',
#  'pip._vendor.html5lib.treewalkers',
#  'distutils.command.os',
#  'ipykernel.jsonutil',
#  'IPython.utils.signatures',
#  'jupyter_client.blocking.time',
#  'time',
#  'pip._vendor.copy',
#  'IPython.core.error',
#  'pip.req.req_file',
#  'pip._vendor.html5lib.html5parser',
#  'pygments.lexers.pygments',
#  'prompt_toolkit.terminal.vt100_output',
#  'email.iterators',
#  'ptyprocess.resource',
#  'pip._vendor.distlib.util',
#  'IPython.utils.simplegeneric',
#  'string',
#  'prompt_toolkit.layout.six',
#  '_elementtree',
#  'email.quoprimime',
#  'subprocess',
#  'zmq.backend.cython.utils',
#  'IPython.core.displayhook',
#  'pip._vendor.packaging.utils',
#  'IPython.core.ultratb',
#  'dis',
#  'compileall',
#  'IPython.core.splitinput',
#  'IPython.lib.types',
#  'pip._vendor.time',
#  'encodings.encodings',
#  'IPython.utils.tempfile',
#  'IPython.extensions.textwrap',
#  'IPython.lib.getpass',
#  'ipython_genutils.sys',
#  'xml.sax.io',
#  'pip._vendor.requests.packages.urllib3._collections',
#  'ptyprocess.pty',
#  'pip._vendor.cachecontrol.serialize',
#  'IPython.lib',
#  '_ctypes',
#  'fnmatch',
#  'pip._vendor.requests.packages.urllib3.util.ssl_',
#  'pip._vendor.distlib.csv',
#  'IPython.core.shadowns',
#  'pexpect.stat',
#  'traitlets.config.json',
#  'email.socket',
#  'weakref',
#  'traitlets',
#  'IPython.core.display',
#  'IPython.terminal',
#  'encodings.binascii',
#  'pip._vendor.html5lib.serializer',
#  'pip._vendor',
#  'email.FeedParser',
#  'IPython.core.json',
#  'pip._vendor.progress.spinner',
#  'email.charset',
#  'IPython',
#  'logging.re',
#  'IPython.core.subprocess',
#  'pip._vendor.distlib.ssl',
#  'email.MIMEMessage',
#  'email._parseaddr',
#  'pip._vendor.distlib.codecs',
#  'prompt_toolkit.layout.abc',
#  'distutils.errno',
#  'traitlets.utils.inspect',
#  'IPython.core.magics.errno',
#  'zmq.sugar.threading',
#  'IPython.core.ast',
#  'prompt_toolkit.clipboard.base',
#  'pip._vendor.cachecontrol.pip',
#  'IPython.core.getipython',
#  'IPython.core.magics.display',
#  'IPython.core.pylabtools',
#  '_ast',
#  'IPython.utils.process',
#  'pip._vendor.os',
#  'tornado.concurrent',
#  'pickle',
#  'xml.sax.types',
#  'pygments.lexers.python',
#  'pkg_resources._vendor.os',
#  'distutils.email',
#  'pathlib2',
#  'ipykernel.comm.ipython_genutils',
#  'pip._vendor.colorama.sys',
#  'xml.etree.ElementPath',
#  'pip._vendor.requests.socket',
#  'IPython.shutil',
#  'pip.utils.pip',
#  'IPython.core.magics.logging',
#  'IPython.lib.warnings',
#  'repr',
#  'pexpect.os',
#  'codeop',
#  'email.parser',
#  'zmq.sugar.atexit',
#  'IPython.core.magics.time',
#  '_weakrefset',
#  'zmq.backend.select',
#  'ipywidgets.widgets.widget',
#  'IPython.core.traitlets',
#  'tty',
#  'pygments.pygments',
#  'backports.shutil_get_terminal_size.termios',
#  'zmq.sugar',
#  'email.MIMEImage',
#  'traitlets.config.warnings',
#  'jupyter_client._version',
#  'pygments.formatters.types',
#  'jupyter_core.os',
#  'platform',
#  'pip.utils.logging',
#  'zmq.libzmq',
#  'pip._vendor.cachecontrol.compat',
#  'pip._vendor.distlib._backport.os',
#  'pexpect.codecs',
#  'ptyprocess.codecs',
#  'IPython.core.traceback',
#  'prompt_toolkit.layout.mouse_handlers',
#  'prompt_toolkit.key_binding.bindings.codecs',
#  'IPython.extensions.traitlets',
#  'email.encoders',
#  'pip._vendor.requests.packages.urllib3.packages.thread',
#  'pip._vendor.types',
#  'backports.shutil_get_terminal_size.struct',
#  'traitlets.utils.ipython_genutils',
#  'ctypes.macholib.framework',
#  'zmq.sugar.frame',
#  'distutils.dist',
#  'IPython.core.magics.history',
#  'zmq.backend.cython.struct',
#  'pip._vendor.requests.api',
#  'ipykernel.signal',
#  'IPython.utils',
#  'prompt_toolkit.layout.time',
#  'pkg_resources._vendor.packaging.__about__',
#  'pygments.filters.re',
#  'IPython.core.magics.IPython',
#  'IPython.utils.capture',
#  'pip._vendor.distlib.collections',
#  'pip._vendor.requests.status_codes',
#  'prompt_toolkit.key_binding.bindings.six',
#  'IPython.core.errno',
#  'pip._vendor.colorama',
#  'IPython.core.re',
#  'IPython.core.copy',
#  'pip._vendor.colorama.ctypes',
#  'pkg_resources._vendor.packaging.markers',
#  'pkg_resources._vendor.packaging.version',
#  'ctypes.macholib.os',
#  'pip._vendor.distlib.pkgutil',
#  'pygments.lexers.sys',
#  'ipykernel.uuid',
#  'pexpect.pty_spawn',
#  'array',
#  'pip._vendor.lockfile.mkdirlockfile',
#  'pip._vendor.cachecontrol.threading',
#  'IPython.core.magics.config',
#  'IPython.utils.PyColorize',
#  'ipykernel.atexit',
#  'IPython.utils._sysinfo',
#  'pip._vendor.distlib',
#  'types',
#  'xml.sax.handler',
#  '_codecs',
#  'pip._vendor.requests.packages.urllib3.connectionpool',
#  'IPython.core.unicodedata',
#  '_osx_support',
#  'IPython.extensions.inspect',
#  'distutils.config',
#  'copy',
#  'pip._vendor.webencodings',
#  'ipywidgets.widgets.sys',
#  'pkg_resources._vendor.pyparsing',
#  'posix',
#  'pip._vendor.cachecontrol.functools',
#  'backports.shutil_get_terminal_size.os',
#  'pip._vendor.requests.codecs',
#  'prompt_toolkit.layout.utils',
#  'zmq.utils.itertools',
#  'getpass',
#  'prompt_toolkit.inspect',
#  'IPython.core.threading',
#  'IPython.utils.text',
#  'xml.etree.cElementTree',
#  'ipython_genutils.os',
#  'IPython.core.pprint',
#  'IPython.core.magics.__future__',
#  'ipywidgets.widgets.datetime',
#  'ipykernel.base64',
#  'tornado',
#  'ipykernel.getpass',
#  'pexpect.errno',
#  'traitlets.config.logging',
#  'pip.vcs.git',
#  'pygments.modeline',
#  'linecache',
#  'ipywidgets.widgets.trait_types',
#  'jupyter_client.zmq',
#  'hmac',
#  'pip._vendor.cachecontrol.zlib',
#  'jupyter_client.json',
#  'datetime',
#  'distutils.getopt',
#  'pip._vendor.distlib._backport.__builtin__',
#  'backports.shutil_get_terminal_size.sys',
#  'ipykernel.datapub',
#  'ptyprocess.time',
#  'pygments.formatters._mapping',
#  'xml',
#  'logging.stat',
#  'pexpect.run',
#  'pip._vendor.html5lib._tokenizer',
#  'IPython.core.magic',
#  '_json',
#  'ipykernel.cPickle',
#  'pyexpat.errors',
#  'traitlets.config.argparse',
#  'IPython.lib.contextlib',
#  '_sysconfigdata',
#  'cProfile',
#  'IPython.lib.re',
#  'pexpect.expect',
#  'zipfile',
#  'zmq.backend.cython.threading',
#  'pip._vendor.requests.structures',
#  'ssl',
#  'tornado.platform.posix',
#  'prompt_toolkit.completion',
#  'resource',
#  'traitlets.config',
#  'pydoc',
#  'threading',
#  'prompt_toolkit.styles.from_dict',
#  'IPython.lib.datetime',
#  'IPython.core.events',
#  'email.Message',
#  'zmq.eventloop.ioloop',
#  'ctypes.macholib.re',
#  'pip._vendor.lockfile.linklockfile',
#  'pkg_resources._vendor.re',
#  'pexpect.sys',
#  'calendar',
#  'ipywidgets',
#  'pip._vendor.requests.packages.urllib3.packages.ssl_match_hostname.ssl',
#  'pip._vendor.distlib.glob',
#  'timeit',
#  'pip.utils.hashes',
#  'plistlib',
#  'jupyter_client.managerabc',
#  'pkg_resources.extern.packaging.version',
#  'zmq.sys',
#  '_MozillaCookieJar',
#  'pip._vendor.itertools',
#  'prompt_toolkit.validation',
#  'fcntl',
#  'pip._vendor.cachecontrol.urlparse',
#  'IPython.utils.path',
#  'distutils.os',
#  'jupyter_client.localinterfaces',
#  'prompt_toolkit.key_binding.bindings.math',
#  'IPython.utils._process_common',
#  'pickleshare',
#  'ipykernel.ipykernel',
#  'json.re',
#  'pip.req.req_uninstall',
#  'distutils.spawn',
#  'opcode',
#  'pstats',
#  'ptyprocess.signal',
#  'pip.utils.codecs',
#  'prompt_toolkit.renderer',
#  'prompt_toolkit.key_binding.bindings.string',
#  'prompt_toolkit.shortcuts',
#  'logging.errno',
#  'xml.sax',
#  'sre_constants',
#  'IPython.lib.backgroundjobs',
#  'certifi',
#  'pip._vendor.distlib._backport.errno',
#  'pip._vendor.packaging',
#  'logging.cPickle',
#  'email.MIMENonMultipart',
#  'pip._vendor.distlib._backport.stat',
#  'prompt_toolkit.layout.screen',
#  'pip.baseparser',
#  'IPython.core.magics.os',
#  'pkg_resources._vendor.packaging.specifiers',
#  'pyexpat',
#  'shutil',
#  'prompt_toolkit.styles.base',
#  'pip._vendor.requests.packages',
#  'prompt_toolkit.key_binding.bindings.basic',
#  'ipywidgets.widgets.__future__',
#  'IPython.core.magics.script',
#  'pygments.formatters.pygments',
#  'prompt_toolkit.buffer',
#  'pkg_resources.extern',
#  'pip._vendor.distlib.io',
#  'importlib.sys',
#  'jupyter_client',
#  'prompt_toolkit.layout.collections',
#  'pip.commands.wheel',
#  'ipykernel.binascii',
#  'pip._vendor.requests.exceptions',
#  'IPython.core.StringIO',
#  'ipywidgets.widgets.widget_output',
#  'heapq',
#  'pip.utils.locale',
#  'pip._vendor.requests.packages.urllib3.poolmanager',
#  'prompt_toolkit.key_binding.bindings.completion',
#  'pip._vendor.distlib.__future__',
#  'pip._vendor.struct',
#  'IPython.core.os',
#  'ctypes.macholib.itertools',
#  'pip._vendor.requests.logging',
#  'IPython.utils.tokenize2',
#  'pip._vendor.colorama.re',
#  'prompt_toolkit.eventloop.six',
#  'prompt_toolkit.filters.collections',
#  'email.Parser',
#  'distutils.types',
#  'traitlets.utils',
#  'pkg_resources.extern.packaging.markers',
#  'pip.operations.freeze',
#  'jupyter_client.channelsabc',
#  'prompt_toolkit.filters.__future__',
#  'zmq.sugar.errno',
#  'pexpect.types',
#  'IPython.utils.frame',
#  'IPython.core.payloadpage',
#  'prompt_toolkit.filters.abc',
#  'prompt_toolkit.layout.prompt',
#  'IPython.core.imp',
#  'IPython.terminal.prompts',
#  'email.Generator',
#  'IPython.core.magic_arguments',
#  'wcwidth.table_wide',
#  'email.MIMEAudio',
#  'IPython.extensions.__future__',
#  'prompt_toolkit.key_binding.bindings.utils',
#  'zmq.utils.jsonapi',
#  'pygments.formatters.re',
#  'pip.models.pip',
#  'prompt_toolkit.eventloop.abc',
#  'IPython.terminal.__future__',
#  'inspect',
#  'prompt_toolkit.styles.utils',
#  'sqlite3.dbapi2',
#  'pip._vendor.distlib._backport.sys',
#  'email.Iterators',
#  'traitlets.warnings',
#  'email.base64MIME',
#  'email.Charset',
#  'zmq.eventloop.sys',
#  'IPython.core.pdb',
#  'ipywidgets.widgets.widget_box',
#  'os',
#  'IPython.terminal.ptutils',
#  'pip._vendor.requests.urllib2',
#  'curses',
#  'pip.commands.pip',
#  'operator',
#  'prompt_toolkit.layout.menus',
#  'pip._vendor.requests.models',
#  'IPython.core.io',
#  'traitlets.config.os',
#  'prompt_toolkit.clipboard.abc',
#  'IPython.lib.imp',
#  'Cookie',
#  '_warnings',
#  'IPython.core.latex_symbols',
#  'pip.utils.filesystem',
#  'IPython.utils.__future__',
#  'prompt_toolkit.layout.__future__',
#  'zmq.backend.cython.zmq',
#  'pip._vendor.requests',
#  'IPython.utils.types',
#  'ipykernel.heartbeat',
#  'pip.req.req_set',
#  'logging.SocketServer',
#  'ipykernel.ipython_genutils',
#  'pip.commands.uninstall',
#  'pip._vendor.cachecontrol.email',
#  'zmq.utils.zmq',
#  'IPython.utils.time',
#  'IPython.lib.hashlib',
#  'IPython.core.__future__',
#  'IPython.utils.glob',
#  'logging.types',
#  'prompt_toolkit.bisect',
#  'IPython.core.release',
#  'pip._vendor.distlib.tempfile',
#  'gettext',
#  '_abcoll',
#  'IPython.lib.security',
#  'zmq.eventloop.Queue',
#  'mimetypes',
#  'pygments.lexers',
#  'IPython.core.formatters',
#  'IPython.warnings',
#  'prompt_toolkit.collections',
#  'email.utils',
#  'prompt_toolkit.layout',
#  'traitlets.re',
#  'IPython.utils.py3compat',
#  'logging.atexit',
#  'traitlets.config.sys',
#  'pip.commands.list',
#  'runpy',
#  'pty',
#  'pip._vendor.distlib.scripts',
#  'jupyter_client.blocking.channels',
#  'pip._vendor.distlib.struct',
#  'pip.commands.help',
#  'prompt_toolkit.key_binding.manager',
#  'zmq',
#  'encodings.utf_8',
#  'json.encoder',
#  'pip._vendor.appdirs',
#  'traitlets.log',
#  'IPython.lib.IPython',
#  'pip._vendor.requests.hashlib',
#  'ctypes.macholib.dyld',
#  'IPython.terminal.unicodedata',
#  'IPython.extensions.IPython',
#  'IPython.core.inspect',
#  'abc',
#  'zmq.utils.sys',
#  'py_compile',
#  'ipython_genutils.errno',
#  'ptyprocess',
#  'jupyter_client.blocking.traitlets',
#  'IPython.core.alias',
#  'IPython.core.datetime',
#  'optparse',
#  'xml.etree',
#  'pip.commands.install',
#  'ipykernel.re',
#  'prompt_toolkit.clipboard.six',
#  'pip._vendor.requests.packages.urllib3.packages',
#  'IPython.utils.shutil',
#  'StringIO',
#  'wcwidth',
#  'ipywidgets.os',
#  'ipykernel.itertools',
#  'pip._vendor.packaging._compat',
#  'pip._vendor.html5lib._trie._base',
#  'pip._vendor.distlib.resources',
#  'ipywidgets.widgets.valuewidget',
#  'select',
#  'pip.commands.logging',
#  'zmq.backend.cython.time',
#  'pkg_resources._vendor.six.moves.urllib',
#  'jupyter_client.session',
#  'pip.vcs.subversion',
#  'IPython.core.keyword',
#  'prompt_toolkit.styles.abc',
#  'IPython.terminal.pt_inputhooks.importlib',
#  'unicodedata',
#  'pip.utils.os',
#  'pip._vendor.requests.packages.urllib3.connection',
#  'zmq.sugar.tracker',
#  'encodings.aliases',
#  'xml.sax._exceptions',
#  'jupyter_core.version',
#  'jupyter_client.launcher',
#  'prompt_toolkit.styles.six',
#  'numbers',
#  'IPython.utils.shlex',
#  'prompt_toolkit.eventloop.base',
#  'pygments.util',
#  'jupyter_client.connect',
#  'pip._vendor.cachecontrol.cache',
#  'traitlets._version',
#  'csv',
#  'jupyter_client.jupyter_core',
#  'htmlentitydefs',
#  'pip._vendor.distlib.threading',
#  'pip._vendor.pkg_resources',
#  'pip._vendor.requests.re',
#  'xml.etree.warnings',
#  'pygments.formatter',
#  'argparse',
#  'pip._vendor.string',
#  'traitlets.config.configurable',
#  'pip._vendor.requests.Cookie',
#  'prompt_toolkit.io',
#  'prompt_toolkit.wcwidth',
#  'jupyter_client.datetime',
#  'traitlets.utils.sentinel',
#  'ptyprocess.os',
#  'pip._vendor.distlib._backport.tarfile',
#  'pkg_resources._vendor.six',
#  'email.urllib',
#  'zmq.sugar.sys',
#  'httplib',
#  'IPython.terminal.interactiveshell',
#  'zmq.backend.cython.context',
#  'token',
#  'prompt_toolkit.auto_suggest',
#  'pip._vendor.cachecontrol.filewrapper',
#  'ptyprocess.fcntl',
#  'IPython.utils.errno',
#  'pip._vendor.__builtin__',
#  'ipywidgets.widgets.itertools',
#  'distutils.warnings',
#  'zmq.utils.strtypes',
#  'pip.commands',
#  'pip._vendor.progress.signal',
#  'IPython.core.interactiveshell',
#  'ipykernel.kernelbase',
#  'ipykernel.errno',
#  'IPython.core.importlib',
#  'ast',
#  'IPython.lib.sys',
#  'zmq.utils.constant_names',
#  'ctypes.struct',
#  'pip._vendor.webencodings.__future__',
#  '_scproxy',
#  'prompt_toolkit.pygments',
#  'IPython.core.logging',
#  'thread',
#  'jupyter_client.jupyter_client',
#  'pip.vcs',
#  'zmq.backend.platform',
#  '_collections',
#  'prompt_toolkit.mouse_events',
#  'prompt_toolkit.key_binding.bindings.__future__',
#  'pip._vendor.six.moves',
#  'ipywidgets.widgets.widget_date',
#  'ipykernel.warnings',
#  'email.Errors',
#  'IPython.utils.locale',
#  'ctypes.sys',
#  'pygments.lexers.__future__',
#  'ipywidgets.widgets.IPython',
#  'prompt_toolkit.filters.cli',
#  'jupyter_client.blocking',
#  'IPython.core.linecache',
#  'json._json',
#  'pip._vendor.requests.warnings',
#  'traitlets.contextlib',
#  'ipykernel.comm.sys',
#  'json.sys',
#  'zmq.sugar.socket',
#  'prompt_toolkit.styles.collections',
#  'ipykernel.comm.logging',
#  'ipython_genutils.shutil',
#  'hashlib',
#  'IPython.core.hashlib',
#  'ipykernel.connect',
#  'sre_compile',
#  'pkg_resources._vendor.threading',
#  'IPython.utils.ulinecache',
#  'pip._vendor.datetime',
#  'IPython.core.bdb',
#  'logging.collections',
#  'email.base64',
#  'encodings.string_escape',
#  'bz2',
#  'prompt_toolkit.terminal.errno',
#  'curses.curses',
#  'IPython.core.completer',
#  'ipykernel.io',
#  'IPython.utils.re',
#  'encodings.ascii',
#  'IPython.utils.inspect',
#  'zmq.backend.cython.sys',
#  'ipywidgets.widgets.base64',
#  'prompt_toolkit.clipboard.__future__',
#  'zmq.backend.cython.random',
#  'pip.req.req_install',
#  'pkg_resources._vendor.collections',
#  'IPython.core.extensions',
#  'pkg_resources.extern.six.moves',
#  'ipykernel.comm',
#  'prompt_toolkit.terminal.six',
#  'jupyter_client.pprint',
#  'logging.os',
#  'ctypes._endian',
#  'ptyprocess.termios',
#  'xml.sax.urlparse',
#  'ipykernel.numbers',
#  'ipywidgets.widgets.ipython_genutils',
#  'IPython.utils.dir2',
#  'prompt_toolkit.styles.defaults',
#  'prompt_toolkit.buffer_mapping',
#  'pip.utils',
#  'pygments.sys',
#  'prompt_toolkit.terminal.termios',
#  'pip._vendor.requests.hooks',
#  'pip._vendor.distlib._backport.fnmatch',
#  'ipykernel.traceback',
#  'IPython.core.payload',
#  '_lsprof',
#  'prompt_toolkit.eventloop.__future__',
#  'IPython.utils._tokenize_py2',
#  'IPython.utils.hashlib',
#  'IPython.utils.IPython',
#  'prompt_toolkit.keys',
#  'ipykernel.comm.manager',
#  'locale',
#  'prompt_toolkit.document',
#  'pip._vendor.packaging.version',
#  'atexit',
#  'email.quopriMIME',
#  'pip.commands.freeze',
#  'IPython.core.autocall',
#  'IPython.core.sys',
#  'IPython.utils.backports',
#  'traitlets.sys',
#  'backports.shutil_get_terminal_size.get_terminal_size',
#  'pygments.StringIO',
#  'IPython.lib.subprocess',
#  'pkg_resources._vendor.string',
#  'IPython.utils._signatures',
#  'pip._vendor.requests.packages.urllib3.util',
#  'pip._vendor.packaging._structures',
#  'struct',
#  'traitlets.config.application',
#  'jupyter_client.socket',
#  'prompt_toolkit.key_binding.bindings',
#  'prompt_toolkit.filters.base',
#  'IPython.utils.decorators',
#  'pdb',
#  'IPython.terminal.signal',
#  'pip._vendor.colorama.os',
#  'pip._vendor.distlib.json',
#  'zmq.eventloop.zmqstream',
#  'IPython.lib.__future__',
#  'jupyter_client.manager',
#  'ipykernel.tornado',
#  'logging.struct',
#  'ipykernel.threading',
#  'distutils.command.string',
#  'prompt_toolkit.filters.prompt_toolkit',
#  'pkg_resources._vendor.sre_constants',
#  'ptyprocess.shutil',
#  'pip._vendor.pip',
#  'ipykernel.parentpoller',
#  'pip.pep425tags',
#  'pip._vendor.requests.packages.urllib3.util.connection',
#  'prompt_toolkit.textwrap',
#  ...]
